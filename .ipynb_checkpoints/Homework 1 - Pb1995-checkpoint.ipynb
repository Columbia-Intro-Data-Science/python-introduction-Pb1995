# %% [markdown]
# ## Problem 1: Set up Github and clone assignment repo.

# %% [markdown]
# - Go to http://www.github.com and create an account.
# - Send your Github username to dg2991@columbia.edu.
# - Install Git - https://github.com/blog/1510-installing-git-from-github-for-mac. Make sure to install command line tools.
# - When I have received your email, you should get a confirmation that you have been added to the repo.
# - Click on this link: https://classroom.github.com/assignment-invitations/11415026d0459793405d3c1ff95cc259
# - Follow the instructions to clone that repo to your local machine.
# - You should type a command like:
#
# ```$ git clone https://github.com/Columbia-Intro-Data-Science/python-introduction-(your-github-username).git```
#
#
# **Next:** Solve the problems directly in this notebook, and then push to the repo above (not to the course repo!)
#
#
# The process should be to create a copy of this notebook, move it into the folder you created above. Then do this:
#
# ``` $ git add mynotebooksolutions.ipynb ```
#
# ``` $ git commit -m "added my homework" ```
#
# ``` $ git push origin master ```

# %% [markdown]
# ## Problem 2: Sales Data Analysis

# %%
# read data into a DataFrame
import pandas as pd
import pylab as plt
import seaborn
from sklearn.linear_model import LinearRegression
import numpy.random as nprnd
import random
import json
pd.set_option('display.max_columns', 500)
# %matplotlib inline

df = pd.read_csv('http://www-bcf.usc.edu/~gareth/ISL/Advertising.csv', index_col=0)
df.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
df[['TV','radio']]
# Out:
#         TV  radio
# 1    230.1   37.8
# 2     44.5   39.3
# 3     17.2   45.9
# 4    151.5   41.3
# 5    180.8   10.8
# 6      8.7   48.9
# 7     57.5   32.8
# 8    120.2   19.6
# 9      8.6    2.1
# 10   199.8    2.6
# 11    66.1    5.8
# 12   214.7   24.0
# 13    23.8   35.1
# 14    97.5    7.6
# 15   204.1   32.9
# 16   195.4   47.7
# 17    67.8   36.6
# 18   281.4   39.6
# 19    69.2   20.5
# 20   147.3   23.9
# 21   218.4   27.7
# 22   237.4    5.1
# 23    13.2   15.9
# 24   228.3   16.9
# 25    62.3   12.6
# 26   262.9    3.5
# 27   142.9   29.3
# 28   240.1   16.7
# 29   248.8   27.1
# 30    70.6   16.0
# ..     ...    ...
# 171   50.0   11.6
# 172  164.5   20.9
# 173   19.6   20.1
# 174  168.4    7.1
# 175  222.4    3.4
# 176  276.9   48.9
# 177  248.4   30.2
# 178  170.2    7.8
# 179  276.7    2.3
# 180  165.6   10.0
# 181  156.6    2.6
# 182  218.5    5.4
# 183   56.2    5.7
# 184  287.6   43.0
# 185  253.8   21.3
# 186  205.0   45.1
# 187  139.5    2.1
# 188  191.1   28.7
# ...

# %% [markdown]
# #### What are the features?
#
# - **TV:** advertising dollars spent on TV for a single product in a given market (in thousands of dollars)
# - **Radio:** advertising dollars spent on Radio
# - **Newspaper:** advertising dollars spent on Newspaper
#
# #### Goal: Predict the number of sales in a given market based on the advertising in TV, Radio and Newspaper.

# %% [markdown]
# ### Problem 2, Part 0: Plot box plots of the coefficient ranges

# %%
df.boxplot()

# %% [markdown]
# ### Problem 2, Part 1: Create scatter plots using plt.scatter()
#
# Create scatter plots of the advertising dollars spent on TV, Radio and Newspaper to the total Sales dollars gained. Fill in the parameter for scatter() below, and simply

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize =((10,3)), sharey = True) 
ax1.scatter(x = df[['TV']], y = df[['sales']], color = "k")
ax1.set_title('Sales vs. TV')
ax1.set_ylabel('Sales')
ax1.set_xlabel('TV')
ax2.scatter(x = df[['radio']], y = df[['sales']], color = "red")
ax2.set_ylabel('Sales')
ax2.set_xlabel('Radio')
ax2.set_title('Sales vs. Radio')
ax3.scatter(x = df[['newspaper']], y = df[['sales']])
ax3.set_ylabel('Sales')
ax3.set_xlabel('Newspaper')
ax3.set_title('Sales vs. Newspaper')

# %%
from pandas.tools.plotting import scatter_matrix 
scatter_matrix(df,figsize=(8,8))
# Out:
# /Users/pranjalbajaj/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11542ce80>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116fa4ef0>]], dtype=object)

# %% [markdown]
# Which of the variables seem correlated with one another? Which don't? Explain your answer

# %% [markdown]
# TV spending seems to be highly correlated with Sales, while Radio spending comes in next and Newspaper sepdning is least correlated with Sales.

# %%
df.corr(method='pearson', min_periods=1)
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %% [markdown]
# Looking at the correlation matrix above, we can see the same relationship.
# Looking at the correlation of sales with all three features, TV has the highest correlation (0.782), next comes in Radio (0.576) and last comes in Newspaper (0.228).

# %% [markdown]
# ### Probelm 2, Part 2: Predict sales using sklearn
#
# - Split data into training and testing subsets.
# - Train model using LinearRegression() from sklearn.linear_model on training data.
# - Evaluate using RMSE and R^2 on testing set
#
#
# If you need help, please refer to this example:
#
# https://github.com/Columbia-Intro-Data-Science/APMAE4990-/blob/master/notebooks/Lecture%202%20-%20Regression%20Bookingdotcom%20Case%20Study.ipynb
#
# See where I split the data into testing/training and evalaute performance.

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# a) Set y to be the sales in df

# %%
y = df[["sales"]]

# %% [markdown]
# b) Set X to be just the features described above in df

# %%
X = df[["TV", "radio", "newspaper"]]

# %% [markdown]
# c) Randomly split data into training and testing - 80% training, 20% testing.

# %%
from sklearn.model_selection import train_test_split
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size = 0.2, random_state = 9598)

# %% [markdown]
# d) Train model on training data, and make predictions on testing data

# %%
Xtest.shape
# Out:
# (40, 3)

# %%
ytest.shape
# Out:
# (40, 1)

# %%
lr = LinearRegression().fit(Xtrain, ytrain)

# %%
ypred = lr.predict(Xtest)

# %% [markdown]
# e) Evalute the R^2 on **testing** data. Is this good? Bad? Why?

# %%
lr.score(Xtest, ytest) #test set score
print('R-Square: %.2f' % r2_score(ytest, ypred))
# Out:
# R-Square: 0.90

# %% [markdown]
# An R-square of 90% is good because it's high. The closer it is to 1.0, the more the variance in test data is explained by the the model, which leads to a higher accuracy score.

# %% [markdown]
# f) Make a scatter plot of your predictions vs the actual values on the testing data. Does it look like a good model?

# %%
plt.scatter(x = ytest, y = ypred, color = "k")
plt.plot(ytest, ytest)
plt.title('Predicted vs. Actual Sales')
plt.ylabel('Predicted Sales')
plt.xlabel('Actual Sales')

# %% [markdown]
# Yes it does seem like a good model as all the points lie very close to the to line ytest = ytest line, indicating high accuracy in prediction.

# %% [markdown]
# g) Can you measure the importance of features in this model? What is something you should check before making conclusions?
# Try looking at LinearRegression().coef_

# %%
({'type':['TV','Radio','Newspaper'],'coef': lr.coef_})
# Out:
# {'coef': array([[ 0.04651522,  0.18019906, -0.00160025]]),
#  'type': ['TV', 'Radio', 'Newspaper']}

# %% [markdown]
# We can measure the feature importance using the coefficients of the features. The lower the coefficient the lower the explaination power of the feature. Based on the results above, the important features are Feature 2 (Radio spending) which has a very high coefficient of 0.18 whereas Feature 1 (TV spending) has a lower coefficient of 0.0465 while Feature 3 (Newspapers spending) has a very small coefficient.
#
# However in order to ** accurately gauge feature importance ** we must scale the data as the plot in question 1 shows that the features are scaled differently and hence their coeffcieients might be catching the effect of differring magnitudes rather than differing variance explaination. Hence, the impact of the scale can affect the coefficients.

# %% [markdown]
# h) What can you conclude from g) - can you think of a way to interpret the result? What should we have done to measure the importance of the features involved?

# %% [markdown]
# #### Now let's scale the data:

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(Xtrain)
scaler.fit(Xtest)
Xtrainscaled = scaler.transform(Xtrain)
Xtestscaled = scaler.transform(Xtest)

# %%
lr_scaled = LinearRegression().fit(Xtrainscaled, ytrain) 
ypred_scaled = lr.predict(Xtest)

# %%
lr_scaled.score(Xtestscaled, ytest) #test set score
print('R-Square: %.2f' % r2_score(ytest, ypred_scaled))
# Out:
# R-Square: 0.90

# %%
({'type':['TV','Radio','Newspaper'],'coef': lr_scaled.coef_})
# Out:
# {'coef': array([[ 3.79110771,  2.72524457, -0.03232761]]),
#  'type': ['TV', 'Radio', 'Newspaper']}

# %%
df.groupby('type')['coef'].mean().plot(kind='bar')

# %% [markdown]
# Having scaled the data, we notice that TV spending now has the highest coefficient followed by Radio spending and then last comes Newspaper spending. Hence, scaling did make a difference and now our coefficients (or weights) are more in accordance with the results we expected based on the correlation coefficients we achieved in in problem 2 part 1 where TV spending had the highest coefficient.

# %% [markdown]
# ** On a further and important note **: According to the coefficients, newspaper advertising has the least affect on sales while radio advertising has the largest influence on sales. L1 (Lasso) and L2 (Ridge) norms can be used for feature selection (and how error changes). In most cases, L1 is better for feature selection.
# Further, criterios such as Akaike information criterion (AIC) or
# Bayesian information criterion (BIC) can be used for fearture selection.

# %% [markdown]
# ## How could you have improved performance?

# %% [markdown]
# *Hint:* Try plotting the data in three dimensions along with the hyperplane solution, and see if you can infer
# a new variable which will help, or try a nonlinear/non-parametric model

# %% [markdown]
# ### 3D Plot

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.formula.api as sm
from matplotlib import cm

csv = pd.read_csv('http://www-bcf.usc.edu/~gareth/ISL/Advertising.csv', index_col=0)
model = sm.ols(formula='sales ~ TV + radio', data = csv)
fit = model.fit()

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')


x_surf = np.arange(0, 350, 20)              
y_surf = np.arange(0, 60, 4)
x_surf, y_surf = np.meshgrid(x_surf, y_surf)


exog = pd.core.frame.DataFrame({'TV': x_surf.ravel(), 'radio': y_surf.ravel()})
out = fit.predict(exog = exog)

# Surface plot
ax.plot_surface(x_surf, y_surf,
                out.reshape(x_surf.shape),
                rstride=1,
                cstride=1,
                color='None',
                alpha = 0.4,cmap=cm.coolwarm)

#Scatterplot
ax.scatter(csv['TV'], csv['radio'], csv['sales'],
           c='blue',
           marker='o',
           alpha=1)

ax.set_xlabel('TV')
ax.set_ylabel('Radio')
ax.set_zlabel('Sales')
plt.show()
# Out:
# /Users/pranjalbajaj/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:24: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead

# %% [markdown]
# ### Feature Engineering: Build Derived Feature and Drop one Feature

# %%
X['TV*radio']=X['TV']*X['radio']
X = X.drop(['newspaper'],1)

# %%
size = float(len(X))

X_train = X[0:int(size*0.8)]
X_test = X[int(size*0.8):]

y_train = y[0:int(size*0.8)]
y_test = y[int(size*0.8):]

regr = LinearRegression()


regr.fit(X_train, y_train)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean square error
print("MSE: %.2f"
      % np.mean((regr.predict(X_test) - y_test) ** 2))
# Explained variance score: 1 is perfect prediction
print('R-square: %.2f' % regr.score(X_test, y_test))
# Out:
# Coefficients:
#  [[ 0.01918396  0.02648516  0.00109794]]
# MSE: 0.39
# R-square: 0.99

# %%
plt.scatter(y_test,regr.predict(X_test))
plt.plot(y_test,y_test,color='r')

# %% [markdown]
# The performance of the model has dramatically improved. The R-square is now 0.99 and all the precited points are now a lot closer to the ytest = ytest line.

# %% [markdown]
# ### New 3D Plot

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.formula.api as sm
from matplotlib import cm

csv = pd.read_csv('http://www-bcf.usc.edu/~gareth/ISL/Advertising.csv', index_col=0)

# Create a linear OLS model with TV:Radio interaction term 
# such that Sales = beta_0 + beta_1 * TV + beta_2 * Radio + beta_3 * Radio * TV
model = sm.ols(formula='sales ~ TV * radio', data = csv)
fit = model.fit()

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')

x_surf = np.arange(0, 350, 20) 
y_surf = np.arange(0, 60, 4)
x_surf, y_surf = np.meshgrid(x_surf, y_surf)

exog = pd.core.frame.DataFrame({'TV': x_surf.ravel(), 'radio': y_surf.ravel()})
out = fit.predict(exog = exog)

# Surface plot
ax.plot_surface(x_surf, y_surf,
                out.reshape(x_surf.shape),
                rstride=1,
                cstride=1,
                color='None',
                alpha = 0.4,cmap=cm.coolwarm)

# Scatter Plot
ax.scatter(csv['TV'], csv['radio'], csv['sales'],
           c='blue',
           marker='o',
           alpha=1)

ax.set_xlabel('TV')
ax.set_ylabel('Radio')
ax.set_zlabel('Sales')

plt.show()
# Out:
# /Users/pranjalbajaj/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:27: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead

# %% [markdown]
# We observe the same good prediciton on the 3-D plot where all the scatter points are a lot closer the the hyperplane.

# %% [markdown]
# ### Non-Linear Model 1: kNN

# %%
from sklearn.neighbors import KNeighborsRegressor
k = KNeighborsRegressor(n_neighbors = 5)
k.fit(Xtrain, ytrain)
ypred_knn = k.predict(Xtest)

# %%
np.mean((ypred_knn - ytest) ** 2) #MSE
# Out:
# 2.0953200000000001

# %%
k.score(Xtest, ytest) #R-square
# Out:
# 0.91424352959834654

# %% [markdown]
# ### Non-Linear Model 2: Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor(max_depth = 5)

# Train the model using the training sets
dt.fit(Xtrain, ytrain)

ypred_dt = dt.predict(Xtest)
ypred_dt = ypred_dt.reshape(40,1)

# %%
np.mean((ypred_dt - ytest) ** 2) #MSE
# Out:
# 1.302604258177789

# %%
dt.score(Xtest, ytest) #R-square
# Out:
# 0.94668750190353201

# %% [markdown]
# ** Non-linear models don't do that well compared to the linear models here. The feature engineered linear model performs the best. **

# %% [markdown]
# ## Problem 3:  Gradient Descent and the learning rate

# %% [markdown]
# By modifying the learning rate below, show how the convergence takes longer or doesn't converge at all.
# Can you explain in words or math why this is?

# %%
from numpy import *

# y = mx + b
# m is slope, b is y-intercept
def compute_error_for_line_given_points(b, m, points):
    totalError = 0
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        totalError += (y - (m * x + b)) ** 2
    return totalError / float(len(points))

def step_gradient(b_current, m_current, points, learningRate):
    b_gradient = 0
    m_gradient = 0
    N = float(len(points))
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        b_gradient += -(2/N) * (y - ((m_current * x) + b_current))
        m_gradient += -(2/N) * x * (y - ((m_current * x) + b_current))
    new_b = b_current - (learningRate * b_gradient)
    new_m = m_current - (learningRate * m_gradient)
    return [new_b, new_m]

def gradient_descent_runner(points, starting_b, starting_m, learning_rate, num_iterations):
    b = starting_b
    m = starting_m
    for i in range(num_iterations):
        b, m = step_gradient(b, m, array(points), learning_rate)
    return [b, m]

def run(num_iterations, learning_rate = 0.00001):
    points = genfromtxt("/Users/pranjalbajaj/Documents/GitHub/APMAE4990-/data/data.csv", delimiter=",")
    learning_rate = 0.0001
    initial_b = 0 # initial y-intercept guess
    initial_m = 0 # initial slope guess
    num_iterations = num_iterations
    print ("Starting gradient descent at b = {0}, m = {1}, error = {2}".format(initial_b, initial_m, compute_error_for_line_given_points(initial_b, initial_m, points)))
    print ("Running...")
    [b, m] = gradient_descent_runner(points, initial_b, initial_m, learning_rate, num_iterations)
    print ("After {0} iterations b = {1}, m = {2}, error = {3}".format(num_iterations, b, m, compute_error_for_line_given_points(b, m, points)))
    for i in range(0,len(points)):
        plt.scatter(points[i,0],points[i,1])
        plt.scatter(points[i,0],m*points[i,0]+b,color='r')

run(100)
# Out:
# Starting gradient descent at b = 0, m = 0, error = 5565.107834483211
# Running...
# After 100 iterations b = 0.03507497059234178, m = 1.4788027175308358, error = 112.64705664288809

# %% [markdown]
# ## Problem 3 Part 2

# %% [markdown]
# Plot the error as a function of the number of iterations for various learning rates. Choose the rates
# so that it tells a story.

# %%
points = genfromtxt("/Users/pranjalbajaj/Documents/GitHub/APMAE4990-/data/data.csv", delimiter=",")

initial_b = 0 # initial y-intercept 
initial_m = 0 # initial slope 
num_iterations = 3

errors=[]
learning_rates = np.logspace(-4,-3,100)

for l in learning_rates:
    learning_rate = l
    [b, m] = gradient_descent_runner(points, initial_b, initial_m, learning_rate, num_iterations)
    errors.append(compute_error_for_line_given_points(b, m, points))

plt.xlabel('Learning Rate')
plt.ylabel('Error ')

plt.plot(learning_rates,errors,label = 'num_iterations='+str(num_iterations))

# %% [markdown]
# #### Visualization 1: A good learning rate
# Learning rate = 0.00001 (default) |
# This produces a small error rate based on the curve above.

# %%
# Use this to visually discuss convergence rate based on learning rate
for num in range(0,10):
    run(num)
    plt.show()
# Out:
# Starting gradient descent at b = 0, m = 0, error = 5565.107834483211
# Running...
# After 0 iterations b = 0, m = 0, error = 5565.107834483211
# Starting gradient descent at b = 0, m = 0, error = 5565.107834483211
# Running...
# After 1 iterations b = 0.014547010110737297, m = 0.7370702973591052, error = 1484.586557408649
# Starting gradient descent at b = 0, m = 0, error = 5565.107834483211
# Running...
# After 2 iterations b = 0.02187396295959641, m = 1.1067954543515157, error = 457.8542575737673
# Starting gradient descent at b = 0, m = 0, error = 5565.107834483211
# Running...
# After 3 iterations b = 0.025579224321293136, m = 1.2922546649131115, error = 199.50998572553894
# Starting gradient descent at b = 0, m = 0, error = 5565.107834483211
# Running...
# After 4 iterations b = 0.027467789559144355, m = 1.385283255651245, error = 134.50591058200533
# Starting gradient descent at b = 0, m = 0, error = 5565.107834483211
# Running...
# ...

# %% [markdown]
# #### Visualization 2: A bad learning rate

# %% [markdown]
# Learning rate = 10 | This produces a larger error rate based on the curve above.

# %%
learning_rate = 10
for num in range(0,10):
    run(num,learning_rate)
    plt.show()
# Out:
# Starting gradient descent at b = 0, m = 0, error = 5565.107834483211
# Running...
# After 0 iterations b = 0, m = 0, error = 5565.107834483211
# Starting gradient descent at b = 0, m = 0, error = 5565.107834483211
# Running...
# After 1 iterations b = 0.014547010110737297, m = 0.7370702973591052, error = 1484.586557408649
# Starting gradient descent at b = 0, m = 0, error = 5565.107834483211
# Running...
# After 2 iterations b = 0.02187396295959641, m = 1.1067954543515157, error = 457.8542575737673
# Starting gradient descent at b = 0, m = 0, error = 5565.107834483211
# Running...
# After 3 iterations b = 0.025579224321293136, m = 1.2922546649131115, error = 199.50998572553894
# Starting gradient descent at b = 0, m = 0, error = 5565.107834483211
# Running...
# After 4 iterations b = 0.027467789559144355, m = 1.385283255651245, error = 134.50591058200533
# Starting gradient descent at b = 0, m = 0, error = 5565.107834483211
# Running...
# ...

# %% [markdown]
# #### Visualization 3: An inefficient learning rate

# %% [markdown]
# Learning rate = 10 | This is inefficient based on the curve above.

# %%
learning_rate = 0.00001
for num in range(0,10):
    run(num,learning_rate)
    plt.show()
# Out:
# Starting gradient descent at b = 0, m = 0, error = 5565.107834483211
# Running...
# After 0 iterations b = 0, m = 0, error = 5565.107834483211
# Starting gradient descent at b = 0, m = 0, error = 5565.107834483211
# Running...
# After 1 iterations b = 0.014547010110737297, m = 0.7370702973591052, error = 1484.586557408649
# Starting gradient descent at b = 0, m = 0, error = 5565.107834483211
# Running...
# After 2 iterations b = 0.02187396295959641, m = 1.1067954543515157, error = 457.8542575737673
# Starting gradient descent at b = 0, m = 0, error = 5565.107834483211
# Running...
# After 3 iterations b = 0.025579224321293136, m = 1.2922546649131115, error = 199.50998572553894
# Starting gradient descent at b = 0, m = 0, error = 5565.107834483211
# Running...
# After 4 iterations b = 0.027467789559144355, m = 1.385283255651245, error = 134.50591058200533
# Starting gradient descent at b = 0, m = 0, error = 5565.107834483211
# Running...
# ...
